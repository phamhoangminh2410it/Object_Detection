# %%
print("test")
# Out:
# test

# %%
# !pip install wandb

# %%
import wandb
wandb.init(project='object_detection')
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241103_185403-u3ybnibj</code>
# Syncing run <strong><a href='https://wandb.ai/phamhoangminh2410it-fpt-software/object_detection/runs/u3ybnibj' target="_blank">absurd-fire-2</a></strong> to <a href='https://wandb.ai/phamhoangminh2410it-fpt-software/object_detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Run with CLI

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 36.6 MB/s eta 0:00:00
# ...

# %%
# No custom data

# !yolo task = detect mode = predict model = yolov8n.pt source = "/content/drive/MyDrive/Dataset_Object/test/valid/images/img323.jpg"

# %%
# Move to
#%cd /content/drive/MyDrive/Dataset_Object/test

# %%
# !ls

# %%
# !pip install ultralytics

# %%
# Custom data with CLI
#%cd /content/drive/MyDrive/Dataset_Object/test

#!yolo train model = yolov8n.pt data = data.yaml epochs=100 imgsz=800 plots = True
#!yolo train model = yolov8n.pt data = data.yaml epochs=100 imgsz=800
# !yolo train model = yolov8n.pt data = /content/drive/MyDrive/Dataset_Object/test/data.yaml epochs = 10 imgsz = 640

# %%
# predict with data train

# !yolo predict model=yolov8n.pt source=/content/drive/MyDrive/Dataset_Object/test/valid/images/img310.jpg

# %% [markdown]
# Run with Python API

# %% [markdown]
# 1. Setup Library

# %%
# !pip install ultralytics

# %% [markdown]
# 2. Predict with python

# %%
from ultralytics import YOLO as yl

# No custom data
source = "/content/drive/MyDrive/Dataset_Object/test/data/img310.jpg"
model = yl("yolov8n.pt")
predict = model.predict(source)

print(predict)

# %% [markdown]
# **Object_Detection**

# %%
# !nvidia-smi
# Out:
# Sun Nov  3 18:54:53 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os

HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display

display.clear_output()
# !yolo checks
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Found existing installation: wandb 0.18.5
# Uninstalling wandb-0.18.5:
#   Successfully uninstalled wandb-0.18.5
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# Disk                32.3/112.6 GB
# CPU                 Intel Xeon 2.00GHz
# CPU count           2
# GPU                 Tesla T4, 15102MiB
# GPU count           1
# CUDA                12.1
#
# numpy               ✅ 1.26.4>=1.23.0
# ...

# %%
from ultralytics import YOLO as yl
from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task = detect mode = predict model = yolov8n.pt source = "drive/MyDrive/Dataset_Object/test/data/img310.jpg"
# Out:
# /content
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Dataset_Object/test/data/img310.jpg: 384x640 5 bikes, 10 carss, 51.0ms
# Speed: 10.0ms preprocess, 51.0ms inference, 822.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename = "runs/detect/predict/img310.jpg", height = 600)
# Out:
# /content

# %%
model = yl(f'{HOME}/yolov8n.pt')
results = model.predict(source = "drive/MyDrive/Dataset_Object/test/data/img310.jpg")

# %%
# %cd {HOME}

# !pip install roboflow

from roboflow import Roboflow

rf = Roboflow(api_key="EcJsr4Wmv0yqE8wRmaFL")
project = rf.workspace("test-az1te").project("object-detection-hzmvx")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# %cd {HOME}

#!yolo task = detect mode = train model = yolov8n.pt data = {dataset.location}/data.yaml epochs = 100 imgsz = 800
# !yolo task = detect mode = train model = yolov8x.pt data = /content/drive/MyDrive/ObjectData/data.yaml epochs = 200 imgsz = 640

# %%
# %cd {HOME}
# !yolo task = detect mode = train model = yolov8n.pt data = /content/drive/MyDrive/ObjectData/data.yaml epochs = 200 imgsz = 640
# Out:
# /content
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=yolov8n.pt data=/content/drive/MyDrive/ObjectData/data.yaml epochs=200 imgsz=640
# Out:
# Ultralytics 8.3.18 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train/

# %%
# %cd {HOME}
Image(filename = f"{HOME}/runs/detect/train2/confusion_matrix.png", width = 600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename = f"{HOME}/runs/detect/train2/results.png", width = 600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename = f"{HOME}/runs/detect/train2/val_batch0_pred.jpg", width = 600)
# Out:
# /content

# %%
# %cd {HOME}
# !yolo task = detect mode = val model = {HOME}/runs/detect/train/weights/best.pt data = /content/drive/MyDrive/ObjectData/data.yaml

# %%
# %cd {HOME}
# !yolo task = detect mode = predict model = {HOME}/runs/detect/train/weights/best.pt conf = 0.25 source = /content/drive/MyDrive/ObjectData/test/images

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/runs/detect/predict/*.jpg')[:1]:
  display(Image(filename = image_path, width = 600))
  print("\n")

# %%
# !yolo task = detect mode = predict model = {HOME}/runs/detect/train/weights/best.pt conf = 0.25 source = "/content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuu1 2017-07-18_08_00_00_000.asf"

# %%
# test with model train
# !yolo task = detect mode = predict model = /content/drive/MyDrive/ObjectData/best8n.pt conf = 0.25 source = "/content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuuRoot.asf"
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# video 1/1 (frame 8725/22869) /content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuuRoot.asf: 384x640 13 bikes, 13 carss, 1 truck, 5.9ms
# video 1/1 (frame 8726/22869) /content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuuRoot.asf: 384x640 13 bikes, 14 carss, 1 truck, 5.8ms
# video 1/1 (frame 8727/22869) /content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuuRoot.asf: 384x640 13 bikes, 14 carss, 1 truck, 6.1ms
# video 1/1 (frame 8728/22869) /content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuuRoot.asf: 384x640 13 bikes, 12 carss, 1 truck, 9.8ms
# video 1/1 (frame 8729/22869) /content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuuRoot.asf: 384x640 16 bikes, 12 carss, 1 truck, 6.4ms
# video 1/1 (frame 8730/22869) /content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuuRoot.asf: 384x640 12 bikes, 12 carss, 1 truck, 5.9ms
# ...

# %% [markdown]
# **Count and Tracking**

# %%
# !pip install ultralytics

# %%
from IPython import display
import ultralytics

display.clear_output()
ultralytics.checks()

# %%
import os

HOME = os.getcwd()
print(HOME)

# %%
# Install ByteTrack

# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass

# %%
# !pip install supervision==0.1.0

# %%
from IPython import display
display.clear_output()

import supervision
print("supervision.__version__:", supervision.__version__)

# %%
# settings
# MODEL = "yolov8x.pt"

MODEL = "/content/drive/MyDrive/ObjectData/best.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()

# %%
from supervision.draw.color import ColorPalette
from supervision.video.source import get_video_frames_generator
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator

# %%
CLASS_NAMES_DICT = model.model.names
CLASS_NAMES_DICT

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - car, motorcycle, bus and truck
CLASS_ID = [0, 1, 2, 3, 5]

# %%
# SOURCE_VIDEO_PATH = "/content/drive/MyDrive/ObjectData/DuongBaTrac-TaQuangBuu8x.avi"

SOURCE_VIDEO_PATH = "/content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuuRoot.asf"

# %%
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=1, text_thickness=1, text_scale=1)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame)
detections = Detections(
    xyxy=results[0].boxes.xyxy.cpu().numpy(),
    confidence=results[0].boxes.conf.cpu().numpy(),
    class_id=results[0].boxes.cls.cpu().numpy().astype(int)
)
# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, confidence, class_id, tracker_id
    in detections
]
# annotate and display frame
frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

# %matplotlib inline
show_frame_in_notebook(frame, (16, 16))

# %%
import numpy as np

print(np.__version__)

# %%
# !pip uninstall numpy -y

# %%
# !pip install numpy==1.23.5

# %%
import numpy as np

@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %%
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator
from supervision.video.sink import VideoSink
import numpy as np

# %%
# settings
LINE_START = Point(50, 1500)
LINE_END = Point(3840-50, 1500)

TARGET_VIDEO_PATH = f"{HOME}/vehicle-counting-result.asf"

# %%
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %%
# from typing import List, Optional
# import numpy as np

# # Assuming Detections and STrack are defined elsewhere
# # Detections should have 'xyxy' and 'confidence' attributes

# # Converts Detections into a format that can be consumed by match_detections_with_tracks function
# def detections2boxes(detections: Detections) -> np.ndarray:
#     if not isinstance(detections.xyxy, np.ndarray):
#         raise ValueError("detections.xyxy must be a numpy array")
#     if not isinstance(detections.confidence, np.ndarray):
#         raise ValueError("detections.confidence must be a numpy array")

#     # Check if the shapes match
#     if detections.xyxy.shape[0] != detections.confidence.shape[0]:
#         raise ValueError("The number of detections and confidence scores must match.")

#     return np.hstack((
#         detections.xyxy,
#         detections.confidence[:, np.newaxis]
#     ))

# # Converts List[STrack] into a format that can be consumed by match_detections_with_tracks function
# def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
#     if not tracks:
#         return np.empty((0, 4), dtype=np.float64)  # Assuming 4 bounding box coordinates

#     return np.array([
#         track.tlbr
#         for track in tracks
#     ], dtype=np.float64)

# # Matches our bounding boxes with predictions
# def match_detections_with_tracks(
#     detections: Detections,
#     tracks: List[STrack]
# ) -> List[Optional[int]]:
#     if len(detections.xyxy) == 0 or len(tracks) == 0:
#         return [None] * len(detections)  # Return None for all detections if empty

#     tracks_boxes = tracks2boxes(tracks=tracks)
#     iou = box_iou_batch(tracks_boxes, detections.xyxy)

#     tracker_ids = [None] * len(detections)

#     # Iterate through detections and find the best track for each
#     for detection_index in range(len(detections)):
#         if len(tracks) > 0:
#             best_tracker_index = np.argmax(iou[:, detection_index])  # Get the best matching tracker
#             if iou[best_tracker_index, detection_index] > 0:  # Ensure it's a valid match
#                 tracker_ids[detection_index] = tracks[best_tracker_index].track_id

#     return tracker_ids

# %%
from tqdm.notebook import tqdm


# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter = LineCounter(start=LINE_START, end=LINE_END)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
line_annotator = LineCounterAnnotator(thickness=4, text_thickness=4, text_scale=2)

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):
        # model prediction on single frame and conversion to supervision Detections
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        # updating line counter
        line_counter.update(detections=detections)
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        line_annotator.annotate(frame=frame, line_counter=line_counter)
        sink.write_frame(frame)

# %%
import numpy as np
print(np.__version__)

# %%
import numpy as np

# Tạo mảng với float
arr = np.array([1.5, 2.5, 3.5], dtype=float)
print(arr)

# %% [markdown]
# ***Test Count and Tracking***

# %%
print("test")

# %%
import numpy as np
print(np.__version__)

# %%
import os

HOME = os.getcwd()
print(HOME)

# %%
# %cd /content

# %%
# %cd {HOME}

# %%
# !git clone https://github.com/MuhammadMoinFaisal/YOLOv8-DeepSORT-Object-Tracking.git

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking

# %%
# !pip install -e '.[dev]'

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"

# %%
# !unzip 'deep_sort_pytorch.zip'

# %%
# !gdown "https://drive.google.com/uc?id=1QZijehoi66eAhNAsy78SnOqatBWfckjl&confirm=t"

# %%
# !gdown "https://drive.google.com/drive/folders/1y66oVMkr3bPuL6P4KGsTyudivjEDqX14"

# %%
# !python predict.py model="/content/drive/MyDrive/ObjectData/best.pt" source="/content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuuRoot.asf"
# !python predict.py source="/content/drive/MyDrive/Dataset_Object/DuongBaTrac-TaQuangBuuRoot.asf" show=True

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train6/test1.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# ###########################################################

# %%
###########################################################

# %%
# !ls
